# %% [markdown]
# # Example usage

# %%
from pyzhenya.pyzhenya import text_to_image, text_to_image_file

# %%
text_to_image('👋')
# Out:
# <PIL.Image.Image image mode=RGBA size=245x247>

# %%
text_to_image_file('🎉', 'emoji.png')

# %% [markdown]
# ![emoji](emoji.png)
